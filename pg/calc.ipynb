# %%
import numpy as np

# %%
A = np.array([[6.76067332e-13, -3.23962357e-13,  5.42999247e-11,  6.26376204e-11], [-3.23962357e-13,  1.55238393e-13, -2.60197924e-11, -3.00151038e-11],
             [5.42999247e-11, -2.60197924e-11,  4.36716487e-09,  5.01810840e-09], [6.26376204e-11, -3.00151038e-11,  5.01810840e-09,  5.83086605e-09]]) * 1e13

# %%
np.linalg.eigvals(A)
# Out:
# array([ 1.01710412e+05,  2.78210705e+02,  4.30405056e-07, -3.17748175e-08])

# %%
k = np.load('../data/estimate/ukf/k/0.npy')

# %%
import matplotlib.pyplot as plt

# %%
for i in range(4):
    plt.plot(k[:, i, i] ** 0.5) 
    plt.show()
