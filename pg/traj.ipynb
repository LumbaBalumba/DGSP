# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
traj_num = 7

# %%
traj = np.load(f'../data/traj/{traj_num}.npy')
traj = traj[:len(traj) // 10]

# %%
traj_est = np.load(f'../data/estimate/ukf/traj/{traj_num}.npy')
traj_est = traj_est[:len(traj_est) // 10]

# %%
len(traj), len(traj_est)
# Out:
# (1000, 1000)

# %%
t1 = np.linspace(0, 1e0, len(traj))
t2 = np.linspace(0, 1e0, len(traj_est))

# %%
for i in range(4):
    plt.plot(t1, traj[:, i])
    plt.plot(t2, traj_est[:, i])
    plt.show()

# %%
x, y = traj[:, 0], traj[:, 1]

# %%
x_est, y_est = traj_est[:, 0], traj_est[:, 1]

# %%
plt.plot(x, y, label='original')
plt.plot(x_est, y_est, label='estimated')
plt.legend()
