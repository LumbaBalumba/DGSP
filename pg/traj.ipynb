# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
traj = np.load('../data/traj/0.npy')

# %%
traj_est = np.load('../data/estimate/ukf/traj/0.npy')

# %%
t1 = np.linspace(0, 10.0, len(traj))
t2 = np.linspace(0, 10.0, len(traj_est))

# %%
for i in range(4):
    plt.plot(t1, traj[:, i])
    plt.plot(t2, traj_est[:, i])
    plt.show()
