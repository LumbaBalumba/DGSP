# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
traj_num = 5

# %%
traj = np.load(f'../data/traj/{traj_num}.npy')

# %%
traj_est = np.load(f'../data/estimate/ukf/traj/{traj_num}.npy')

# %%
t1 = np.linspace(0, 10.0, len(traj))
t2 = np.linspace(0, 10.0, len(traj_est))

# %%
for i in range(4):
    plt.plot(t1, traj[:, i])
    plt.plot(t2, traj_est[:, i])
    plt.show()
