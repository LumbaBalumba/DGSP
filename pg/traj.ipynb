# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
traj_num = 0

# %%
traj = np.load(f'../data/traj/{traj_num}.npy')

# %%
traj_est = np.load(f'../data/estimate/ukf/traj/{traj_num}.npy')

# %%
len(traj), len(traj_est)
# Out:
# (1001, 1002)

# %%
t1 = np.linspace(0, 0.1, len(traj))
t2 = np.linspace(0, 0.1, len(traj_est))

# %%
for i in range(4):
    plt.plot(t1, traj[:, i])
    plt.plot(t2, traj_est[:, i])
    plt.show()

# %%
x, y = traj[:, 0], traj[:, 1]

# %%
x_est, y_est = traj_est[:, 0], traj_est[:, 1]

# %%
plt.plot(x, y)
plt.plot(x_est, y_est)
