# %%
import sympy as sp

# %%
t = sp.symbols('t')

# %%
x = sp.IndexedBase('x')

# %%
f = sp.Matrix(
    [
        x[0] * x[1],
        sp.sin(x[0])
    ]
)

f
# Out:
# Matrix([
# [x[0]*x[1]],
# [sin(x[0])]])

# %%
f.jacobian([x[0], x[1]])
# Out:
# Matrix([
# [     x[1], x[0]],
# [cos(x[0]),    0]])

# %%
type([sp.hessian(f[i], [x[0], x[1]]) for i in range(2)][0])
# Out:
# sympy.matrices.dense.MutableDenseMatrix

# %%
H = z
H
# Out:
# [[[0, 1], [1, 0]], [[-sin(x[0]), 0], [0, 0]]]
